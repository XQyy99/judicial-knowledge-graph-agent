# %% [markdown]
# ## 爬虫

# %%
import requests as req
import re
url='http://wenshu.court.gov.cn/List/ListContent?'
my_headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
                'Referer':'http://wenshu.court.gov.cn/List/List?sorttype=1&conditions=searchWord+2+AJLX++%E6%A1%88%E4%BB%B6%E7%B1%BB%E5%9E%8B:%E6%B0%91%E4%BA%8B%E6%A1%88%E4%BB%B6'
               }
data={'Param':'案件类型:民事案件', 'Index': 2,'Page':'5','Order':'法院层级','Direction':'asc'}
r=req.post(url,headers=my_headers,data=data)
raw=r.json()
pattern1= re.compile('"裁判日期":"(.*?)"',re.S)
date= re.findall(pattern1,raw)
pattern2= re.compile('"案号":"(.*?)"',re.S)
num= re.findall(pattern2,raw)
pattern3= re.compile('"案件名称":"(.*?)"',re.S)
title= re.findall(pattern3,raw)
pattern4= re.compile('"裁判要旨段原文":"(.*?)"',re.S)
content= re.findall(pattern4,raw)
content
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/miniconda3/envs/sblb/lib/python3.8/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/miniconda3/envs/sblb/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# File ~/opt/miniconda3/envs/sblb/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/opt/miniconda3/envs/sblb/lib/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 9
#       7 data={'Param':'案件类型:民事案件', 'Index': 2,'Page':'5','Order':'法院层级','Direction':'asc'}
#       8 r=req.post(url,headers=my_headers,data=data)
# ----> 9 raw=r.json()
#      10 pattern1= re.compile('"裁判日期":"(.*?)"',re.S)
#      11 date= re.findall(pattern1,raw)
#
# File ~/opt/miniconda3/envs/sblb/lib/python3.8/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import pandas as pd 
# df=pd.read_csv(r"G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\2021年10月裁判文书数据.csv")
# df.head(1)
import os

# 定义文件路径和文件名的模式
base_path = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据"
file_names = [f"2020年{str(month).zfill(2)}月裁判文书数据.csv" for month in range(12, 13)] 

# 读取并合并CSV文件
month=12
for file in file_names:
    file_path = os.path.join(base_path, file)
    if os.path.exists(file_path):
        print(f"正在读取: {file_path}")
        df = pd.read_csv(file_path)
        df=df[df['案由'].str.contains("吸毒|毒品",na=False)]
        df=df.dropna()
        df=df.reset_index(drop=True)
        output_path=os.path.join(base_path,f"毒品{month}.csv")
        df.to_csv(output_path,index=False)
        month+=1
        del df
    else:
        print(f"文件未找到: {file_path}")
# Out:
# 正在读取: G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\2020年12月裁判文书数据.csv

# %% [markdown]
# ## 数据筛选并转json

# %%
import os
import pandas as pd 
base_path = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据"
file_names = [f"毒品{str(month).zfill(1)}.csv" for month in range(1, 13)] 
dataFrames=[]
for file in file_names:
    file_path = os.path.join(base_path, file)
    df=pd.read_csv(file_path)
    df.dropna(inplace=True)
    dataFrames.append(df)
merged_df=pd.concat(dataFrames,ignore_index=True)
merged_df.reset_index()
merged_df.to_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.csv',index=False)

# %%
merged_df.head(1)
# Out:
#                                                 原始链接                案号  \
# 0  https://wenshu.court.gov.cn/website/wenshu/181...  （2020）鄂0107刑初50号
#
#          案件名称             法院    所属地区  案件类型  案件类型编码                 来源  审理程序  \
# 0  高光坚一审刑事判决书  湖北省武汉市青山区人民法院  湖北省武汉市  刑事案件       4  www.macrodatas.cn  刑事一审
#
#          裁判日期        公开日期  当事人             案由  \
# 0  2020-01-08  2020-01-14  高光坚  走私、贩卖、运输、制造毒品
#
#                                                 法律依据  \
# 0  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
#
#                                                   全文
# 0  湖北省武汉市青山区人民法院刑 事 判 决 书（2020）鄂0107刑初50号公诉机关湖北省武...

# %%
import pandas as pd 
#df=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.csv')
df=merged_df
length_series = df['全文'].str.len()

# %%
df=df.reset_index()
df.head(1)
# Out:
#    index                                               原始链接                案号  \
# 0      0  https://wenshu.court.gov.cn/website/wenshu/181...  （2020）鄂0107刑初50号
#
#          案件名称             法院    所属地区  案件类型  案件类型编码                 来源  审理程序  \
# 0  高光坚一审刑事判决书  湖北省武汉市青山区人民法院  湖北省武汉市  刑事案件       4  www.macrodatas.cn  刑事一审
#
#          裁判日期        公开日期  当事人             案由  \
# 0  2020-01-08  2020-01-14  高光坚  走私、贩卖、运输、制造毒品
#
#                                                 法律依据  \
# 0  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
#
#                                                   全文
# 0  湖北省武汉市青山区人民法院刑 事 判 决 书（2020）鄂0107刑初50号公诉机关湖北省武...

# %%
df.isnull().sum()
# Out:
# index         0
# Unnamed: 0    0
# 原始链接          0
# 案号            0
# 案件名称          0
# 法院            0
# 所属地区          0
# 案件类型          0
# 案件类型编码        0
# 来源            0
# 审理程序          0
# 裁判日期          0
# 公开日期          0
# 当事人           0
# 案由            0
# 法律依据          0
# 全文            0
# dtype: int64

# %%
df.to_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.csv',index=False)

# %%
length_distribution = length_series.value_counts()
print(length_distribution)
# Out:
# 全文
# 782     23
# 992     20
# 900     20
# 844     20
# 725     20
#         ..
# 503      1
# 156      1
# 1333     1
# 2059     1
# 1807     1
# Name: count, Length: 1911, dtype: int64

# %%
length_series.hist(bins=range(length_series.min(), length_series.max() + 2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 length_series.hist(bins=range(length_series.min(), length_series.max() + 2))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import re

def extract_party_info(text):
    # Pattern to extract the defendant's information
    party_info_pattern = r"被告人(.*?)(，.*?，.*?，.*?出生)"
    
    # Search for the basic information
    match = re.search(party_info_pattern, text, re.S)
    if not match:
        return None  # 如果匹配不到，直接返回 None
    
    party_info = match.group(0)
    
    # Extract specific fields using regex and check for None before accessing group
    name_match = re.search(r"被告人(.*?)[，。]", party_info)
    name = name_match.group(1).strip() if name_match else ""
    
    gender_match = re.search(r"，(男|女)[，。]", party_info)
    gender = gender_match.group(1).strip() if gender_match else ""
    
    ethnicity_match = re.search(r"，(汉族|满族|蒙古族|壮族)[，。]", party_info)
    ethnicity = ethnicity_match.group(1).strip() if ethnicity_match else ""
    
    birth_date_match = re.search(r"(\d{4}年\d{1,2}月\d{1,2}日)出生", party_info)
    birth_date = birth_date_match.group(1).strip() if birth_date_match else ""
    
    # Extract birthplace if it exists
    birthplace_match = re.search(r"出生于(.*?省.*?市)", text)
    birthplace = birthplace_match.group(1).strip() if birthplace_match else ""

    return {
        "姓名": name,
        "性别": gender,
        "民族": ethnicity,
        "出生年月": birth_date,
        "户籍地": birthplace  # No explicit field in the text
    }


def extract_judgment_info(text):
    # 提取公诉机关
    prosecution_match = re.search(r"公诉机关(.*?人民检察院)", text)
    prosecution = prosecution_match.group(1).strip() if prosecution_match else ""

    # 提取结尾的审判员
    judge_match = re.search(r"审判员\s+(\S+)$", text, re.M)
    judge = judge_match.group(1).strip() if judge_match else ""
    # 提取审判长
    presiding_judge_match = re.search(r"审\s*判\s*长\s+(\S+)", text)
    presiding_judge = presiding_judge_match.group(1).strip() if presiding_judge_match else ""

    # 提取书记员
    clerk_match = re.search(r"书\s*记\s*员\s+(\S+)", text)
    clerk = clerk_match.group(1).strip() if clerk_match else ""
    return {
        "公诉机关": prosecution,
        "审判员": judge,
        "审判长": presiding_judge,
        "书记员": clerk
    }

def extract_main_body(text):
    # 正则表达式匹配正文的开始和结束
    main_body_pattern = r"(指控被告人.*?犯.*?罪)(.*?如不服本判决)"
    match = re.search(main_body_pattern, text, re.S)
    
    if match:
        # 提取正文部分
        main_body = match.group(0).strip()
        return main_body
    else:
        # 如果没有找到正文，返回空字符串
        return ""

def assemble_to_json(text):
    # 调用各个提取函数
    party_info = extract_party_info(text)
    judgment_info = extract_judgment_info(text)
    main_body = extract_main_body(text)
    
    # 构建 JSON 格式
    result = {
        "首部": {
            "公诉机关": judgment_info.get("公诉机关", "")
        },
        "当事人基本情况": party_info if party_info else {},
        "正文部分": {
            "文本": main_body
        },
        "落款": {
            "审判长": judgment_info.get("审判长", ""),
            "审判员": judgment_info.get("审判员", ""),
            "书记员": judgment_info.get("书记员", "")
        }
    }

    return [result]    
# Example input text
judgment_text = """
四川省金阳县人民法院 刑 事 判 决 书 （2021）川3430刑初5号 公诉机关四川省金阳县人民检察院。 被告人勒古木尔作，女，现年36岁（1984年5月6日出生），彝族，文盲，村民，户籍所在地四川省金阳县，捕前住四川省金阳县，因犯贩卖毒品罪、容留他人吸毒罪，于2016年3月27日被莆田市公安局荔城分局刑事拘留（3月26日被抓获），经莆田市公安局荔城分局决定，于2016年4月23日被取保候审。该案于2019年8月8日移送四川省凉山州金阳县公安局管辖，金阳县。经四川省金阳县人民法院决定，于2021年1月18日被金阳县公安局执行逮捕。现羁押于金阳县看守所。 四川省金阳县人民检察院以金检一部刑诉［2020］Z48号起诉书指控被告人勒古木尔作犯贩卖毒品罪、容留他人吸毒罪，于2021年1月5日向本院提起公诉，本院依法组成合议庭，公开开庭审理了本案。金阳县人民检察院指派检察员白史则出庭支持公诉。翻译人员此么春立，被告人勒古木尔作到庭参加诉讼，现已审理终结。 四川省金阳县人民检察院指控：2016年3月初至3月26日期间，苏某（另案处理）勒古木尔作共同出资购买毒品海洛因5克，之后分别于2016年3月8日、3月25日、3月26日在福建省莆田市荔城区&times;&times;镇&times;&times;村&times;&times;人居住的出租屋内（房东余某）三次共同以0.1克／50.00元人民币的价格贩卖0.1克毒品海洛因给吸毒人员哑某并容留哑某在房间内吸食。苏某、勒古木尔作分别于2016年3月10日左右、3月26日在莆田市荔城区&times;&times;镇&times;&times;村&times;&times;人居住的出租屋内两次共同以0.1克／50.00元人民币的价格贩卖0.1克毒品海洛因给吸毒人员黄某并容留黄某在房间内当场吸食。苏某、勒古木尔作分别于2016年3月24日、3月25日、3月26日在莆田市荔城区&times;&times;镇&times;&times;村&times;&times;人居住的出租屋
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, TimeoutError


def process_csv_to_json(input_csv_path, output_json_path, start_row=0, timeout=5):
    # 读取 CSV 文件
    df = pd.read_csv(input_csv_path)

    # 确保有“全文”列
    
    if "全文" not in df.columns:
        raise ValueError("输入的 CSV 文件必须包含 '全文' 列")

    # 打开 JSON 文件，以追加模式写入数据
    with open(output_json_path, "w", encoding="utf-8") as json_file:
        json_file.write("[\n")  # 写入 JSON 文件的开始部分

        # 从指定行开始遍历
        for index, row in tqdm(df.iloc[start_row:].iterrows(), 
                               total=len(df) - start_row, 
                               desc='Processing', 
                               unit='rows', 
                               dynamic_ncols=True):
            text = row["全文"]
            if (len(text)>3500):
                continue
            try:
                # 使用 ThreadPoolExecutor 来设置超时
                with ThreadPoolExecutor(max_workers=1) as executor:
                    future = executor.submit(assemble_to_json, text)
                    processed_data = future.result(timeout=timeout)

                for item in processed_data:
                    item["index"] = row["index"]
                    
                # 写入处理后的 JSON 数据
                for i, item in enumerate(processed_data):
                    json.dump(item, json_file, ensure_ascii=False, indent=4)
                    # 仅在最后一行不加逗号
                    if index != len(df) - 1 or i != len(processed_data) - 1:
                        json_file.write(",\n")
            except TimeoutError:
                print(f"处理第 {index} 行超时，跳过该行。")
            except Exception as e:
                print(f"处理第 {index} 行时出错，跳过该行。错误信息: {e}")

        json_file.write("\n]")  # 写入 JSON 文件的结束部分

    print(f"处理完成，结果已保存到 {output_json_path}")

# 示例用法
input_csv = r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.csv'
output_json = r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.json'
start_row = 0  # 从第 845 行开始处理

process_csv_to_json(input_csv, output_json, start_row=start_row)
# Out:
# Processing: 100%|██████████| 131521/131521 [13:03:34<00:00,  2.80rows/s]
# 处理完成，结果已保存到 G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.json

# %%
import json

# 读取 JSON 文件
with open(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# 定义过滤逻辑
filtered_data = []
for item in data:
    # 确保有'正文部分'和'当事人基本情况'键
    if '正文部分' in item and '当事人基本情况' in item:
        # 获取必要的字段
        text = item['正文部分'].get('文本', '').strip()
        basic_info = item['当事人基本情况']
        # 检查文本和当事人基本情况的必要字段是否不为空
        if text and all(basic_info.get(key, '').strip() for key in ['姓名', '性别', '民族', '出生年月']):
            filtered_data.append(item)

# 输出或保存过滤后的数据
with open(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allfilter.json', 'w', encoding='utf-8') as file:
    json.dump(filtered_data, file, ensure_ascii=False, indent=4)

print(f"过滤完成，共保留 {len(filtered_data)} 条数据。")
# Out:
# 过滤完成，共保留 4452 条数据。

# %% [markdown]
# ### 数据标注

# %%
import json

def clean_text(text):
    """
    删除文本中的 &time; 字符。
    """
    return text.replace("&times;", "")

def process_json(input_json_file, output_json_file):
    # 打开 JSON 文件
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 遍历数据并清理 "正文部分" 中的 "文本"
    for record in data:
        if "正文部分" in record and "文本" in record["正文部分"]:
            original_text = record["正文部分"]["文本"]
            cleaned_text = clean_text(original_text)
            record["正文部分"]["文本"] = cleaned_text
        if "当事人基本情况" in record and "户籍地" in record["当事人基本情况"]:
            original_text = record["当事人基本情况"]["户籍地"]
            cleaned_text = clean_text(original_text)
            record["当事人基本情况"]["户籍地"] = cleaned_text
    
    # 将结果保存到输出文件
    with open(output_json_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    
    print(f"处理完成！结果已保存到 {output_json_file}")

# 使用示例
input_json_file = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allfilter.json"  # 输入 JSON 文件路径
output_json_file = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json"  # 输出清理后的 JSON 文件路径

process_json(input_json_file, output_json_file)
# Out:
# 处理完成！结果已保存到 G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json

# %%
# import json
# import random

# def split_text(text, min_len=100, max_len=200):
#     """
#     将文本分割为指定长度的段落，长度在 min_len 和 max_len 之间随机生成。
#     """
#     chunks = []
#     i = 0
#     while i < len(text):
#         segment_length = random.randint(min_len, max_len)
#         chunks.append(text[i:i + segment_length])
#         i += segment_length
#     return chunks

# def process_json_to_txt(input_json_file, output_txt_file):
#     # 打开 JSON 文件
#     with open(input_json_file, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     # 准备保存的内容
#     result_lines = []
    
#     for record in data:
#         # 提取 "正文部分" 中的 "文本"
#         text = record.get("正文部分", {}).get("文本", "")
#         if text:
#             # 按段分割文本
#             split_chunks = split_text(text)
#             result_lines.extend(split_chunks)
    
#     # 打乱所有数据
#     random.shuffle(result_lines)
    
#     # 将结果保存到 TXT 文件
#     with open(output_txt_file, 'w', encoding='utf-8') as f:
#         for line in result_lines:
#             f.write(line + "\n")
    
#     print(f"处理完成！结果已保存到 {output_txt_file}")

# # 使用示例
# input_json_file = "/Users/yuu/Downloads/毕业设计/spider_bysj/tmp/毒品clean.json"  # 输入 JSON 文件路径
# output_txt_file = "/Users/yuu/Downloads/毕业设计/spider_bysj/tmp/drug.txt"  # 输出 TXT 文件路径

# process_json_to_txt(input_json_file, output_txt_file)

# %%
import json
import re

def extract_penalty(text):
    """
    从文本中提取判罚内容，包括刑期和罚金。
    """
    penalty = {"刑期": "", "罚金": ""}
    
    # 匹配刑期，如“有期徒刑一年五个月”、“拘役六个月”或“有期徒刑六个月”
    prison_pattern = r"(有期徒刑[一二三四五六七八九十零○百千\d]+年[一二三四五六七八九十零○百千\d]*个月*|有期徒刑[一二三四五六七八九十零○百千\d]+个月*|拘役[一二三四五六七八九十零○百千\d]+年[一二三四五六七八九十零○百千\d]*个月*|拘役[一二三四五六七八九十零○百千\d]+个月*)"
    prison_match = re.search(prison_pattern, text)
    if prison_match:
        penalty["刑期"] = prison_match.group()
    
    # 匹配罚金，如“罚金人民币八千元”
    fine_pattern = r"罚金人民币[一二三四五六七八九十百千万亿零○\d]+元"
    fine_match = re.search(fine_pattern, text)
    if fine_match:
        penalty["罚金"] = fine_match.group()
    
    return penalty

def process_json(input_file, output_file):
    """
    从输入 JSON 文件提取判罚内容，并将其写入到新的 JSON 文件中。
    """
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    for record in data:
        if "正文部分" in record and "文本" in record["正文部分"]:
            text = record["正文部分"]["文本"]
            # 提取判罚内容
            penalty = extract_penalty(text)
            # 写入 "判罚" 部分
            record["判罚"] = penalty
    
    # 保存到输出文件
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    
    print(f"处理完成！结果已保存到 {output_file}")
# 使用示例
input_json_file = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json"
output_json_file = r"G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json"  # 输出 JSON 文件路径

process_json(input_json_file, output_json_file)
# Out:
# 处理完成！结果已保存到 G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json

# %%
file_path=r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品allclean.json'
with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file) 

import pandas as pd 
df=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all.csv')
df1 = pd.DataFrame(columns=['index', '案号', '案件名称','法院','所属地区','审理程序','裁判日期','当事人','案由','法律依据'])
index_list=[]
for record in data:
        index_list.append(record['index'])
df_filtered = df.loc[index_list]

# %%
df_filtered=df_filtered[['index', '案号', '案件名称','法院','所属地区','审理程序','裁判日期','当事人','案由','法律依据']]
df_filtered.columns
# Out:
# Index(['index', '案号', '案件名称', '法院', '所属地区', '审理程序', '裁判日期', '当事人', '案由',
#        '法律依据'],
#       dtype='object')

# %%
df_filtered
# Out:
#          index                  案号                             案件名称  \
# 12          12  （2019）浙0702刑初1039号      赵雨、姚世杰走私、贩卖、运输、制造毒品罪一审刑事判决书
# 13          13  （2019）桂0107刑初1151号          钟光走私、贩卖、运输、制造毒品罪一审刑事判决书
# 26          26     （2020）浙0203刑初7号      刘军、刘晓琳走私、贩卖、运输、制造毒品罪一审刑事判决书
# 58          58    （2020）湘1281刑初22号               岳元玉、朱贤滨贩卖毒品一审刑事判决书
# 75          75   （2019）浙1102刑初727号     叶丽剑、郑于川走私、贩卖、运输、制造毒品罪一审刑事判决书
# ...        ...                 ...                              ...
# 131387  131387   （2020）桂0203刑初575号  江祖煌、卢剑、陈柏成走私、贩卖、运输、制造毒品罪一审刑事判决书
# 131452  131452   （2020）川0105刑初860号       周溢、易伟走私、贩卖、运输、制造毒品罪一审刑事判决书
# 131461  131461   （2020）桂0802刑初564号                   邱同旺、张福林一审刑事判决书
# 131512  131512   （2020）渝0113刑初630号       韩静,刘涛走私、贩卖、运输、制造毒品罪一审刑事判决书
# 131516  131516  （2020）粤0307刑初2983号    敬岩峰、唐华琴走私、贩卖、运输、制造毒品刑事一审刑事判决书
#
#                        法院        所属地区  审理程序        裁判日期          当事人  \
# 12             金华市婺城区人民法院         金华市  刑事一审  2020-01-03       姚世杰；赵雨
# 13            南宁市西乡塘区人民法院         南宁市  刑事一审  2020-01-07           钟光
# 26             宁波市海曙区人民法院         宁波市  刑事一审  2020-01-07       刘晓琳；刘军
# 58             湖南省洪江市人民法院      湖南省洪江市  刑事一审  2020-01-06      岳元玉；朱贤滨
# 75             丽水市莲都区人民法院         丽水市  刑事一审  2020-01-10      叶丽剑；郑于川
# ...                   ...         ...   ...         ...          ...
# 131387         柳州市鱼峰区人民法院         柳州市  刑事一审  2020-12-09   江祖煌；卢剑；陈柏成
# 131452         成都市青羊区人民法院         成都市  刑事一审  2020-12-22        周溢；易伟
# 131461  广西壮族自治区贵港市港北区人民法院  广西壮族自治区贵港市  刑事一审  2020-12-18  邱同旺；张福林；刘展红
# 131512         重庆市巴南区人民法院         重庆市  刑事一审  2020-12-04        韩静；刘涛
# 131516      广东省深圳市龙岗区人民法院      广东省深圳市  刑事一审  2020-12-14      敬岩峰；唐华琴
#
#                    案由                                               法律依据
# 12      走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 13      走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 26      走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 58      走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 75      走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# ...               ...                                                ...
# 131387  走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 131452  走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 131461  走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 131512  走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 131516  走私、贩卖、运输、制造毒品  《中华人民共和国刑法（1997年）》:第三百四十七条第一款；《中华人民共和国刑法（1997年...
# 4449      黄  有期徒刑一年三个月  罚金人民币三千元
# 4450           有期徒刑九个月
# 4451    邱婉仪  有期徒刑一年八个月  罚金人民币四千元
#
# [4452 rows x 13 columns]

# %%
df_json.columns
# Out:
# Index(['index', '首部.公诉机关', '当事人基本情况.姓名', '当事人基本情况.性别', '当事人基本情况.民族',
#        '当事人基本情况.出生年月', '当事人基本情况.户籍地', '正文部分.文本', '落款.审判长', '落款.审判员', '落款.书记员',
#        '判罚.刑期', '判罚.罚金'],
#       dtype='object')

# %%
df_json=df_json[['index', '首部.公诉机关', '当事人基本情况.姓名', '当事人基本情况.性别', '当事人基本情况.民族',
       '当事人基本情况.出生年月',  '正文部分.文本', '判罚.刑期', '判罚.罚金']]
df_json.columns
# Out:
# Index(['index', '首部.公诉机关', '当事人基本情况.姓名', '当事人基本情况.性别', '当事人基本情况.民族',
#        '当事人基本情况.出生年月', '正文部分.文本', '判罚.刑期', '判罚.罚金'],
#       dtype='object')

# %%
df_merged = pd.merge(df_filtered, df_json, on='index', how='left')

# 重命名列以去掉 "正文部分." 前缀（可选）
df_merged.rename(columns={"正文部分.文本": "文本","首部.公诉机关":"公诉机关","当事人基本情况.姓名":"姓名","当事人基本情况.姓别":"姓别","当事人基本情况.民族":"民族","当事人基本情况.出生年月":"出生年月","判罚.刑期":"刑期","判罚.罚金":"罚金"}, inplace=True)
df_merged
# Out:
#        index                  案号                             案件名称  \
# 0         12  （2019）浙0702刑初1039号      赵雨、姚世杰走私、贩卖、运输、制造毒品罪一审刑事判决书
# 1         13  （2019）桂0107刑初1151号          钟光走私、贩卖、运输、制造毒品罪一审刑事判决书
# 2         26     （2020）浙0203刑初7号      刘军、刘晓琳走私、贩卖、运输、制造毒品罪一审刑事判决书
# 3         58    （2020）湘1281刑初22号               岳元玉、朱贤滨贩卖毒品一审刑事判决书
# 4         75   （2019）浙1102刑初727号     叶丽剑、郑于川走私、贩卖、运输、制造毒品罪一审刑事判决书
# ...      ...                 ...                              ...
# 4447  131387   （2020）桂0203刑初575号  江祖煌、卢剑、陈柏成走私、贩卖、运输、制造毒品罪一审刑事判决书
# 4448  131452   （2020）川0105刑初860号       周溢、易伟走私、贩卖、运输、制造毒品罪一审刑事判决书
# 4449  131461   （2020）桂0802刑初564号                   邱同旺、张福林一审刑事判决书
# 4450  131512   （2020）渝0113刑初630号       韩静,刘涛走私、贩卖、运输、制造毒品罪一审刑事判决书
# 4451  131516  （2020）粤0307刑初2983号    敬岩峰、唐华琴走私、贩卖、运输、制造毒品刑事一审刑事判决书
#
#                      法院        所属地区  审理程序        裁判日期          当事人  \
# 0            金华市婺城区人民法院         金华市  刑事一审  2020-01-03       姚世杰；赵雨
# 1           南宁市西乡塘区人民法院         南宁市  刑事一审  2020-01-07           钟光
# 2            宁波市海曙区人民法院         宁波市  刑事一审  2020-01-07       刘晓琳；刘军
# 3            湖南省洪江市人民法院      湖南省洪江市  刑事一审  2020-01-06      岳元玉；朱贤滨
# 4            丽水市莲都区人民法院         丽水市  刑事一审  2020-01-10      叶丽剑；郑于川
# 4450  指控被告人韩静、刘涛犯贩卖毒品罪，于2020年11月16日向本院提起公诉。本院依法适用认罪认...    有期徒刑九个月
# 4451  指控被告人敬岩峰、唐华琴犯贩卖毒品罪，于2020年11月16日向本院提起公诉，并建议适用简易...  有期徒刑一年八个月  罚金人民币四千元
#
# [4452 rows x 18 columns]

# %%
df_merged['罪名'] = df_merged['案由'].astype(str) + '罪'
df_merged['罪名']
# Out:
# 0       走私、贩卖、运输、制造毒品罪
# 1       走私、贩卖、运输、制造毒品罪
# 2       走私、贩卖、运输、制造毒品罪
# 3       走私、贩卖、运输、制造毒品罪
# 4       走私、贩卖、运输、制造毒品罪
#              ...
# 4447    走私、贩卖、运输、制造毒品罪
# 4448    走私、贩卖、运输、制造毒品罪
# 4449    走私、贩卖、运输、制造毒品罪
# 4450    走私、贩卖、运输、制造毒品罪
# 4451    走私、贩卖、运输、制造毒品罪
# Name: 罪名, Length: 4452, dtype: object

# %%
df_merged.to_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品all_clean.csv',index=False)

# %%
import pandas as pd 
df1=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\毒品5_clean.csv')
df2=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\毒品6_clean.csv')
result = pd.concat([df1, df2], axis=0, ignore_index=True)
result
# Out:
#      index                 案号                                 案件名称  \
# 0       17  （2020）鲁0303刑初510号          王吉群、董佳伟走私、贩卖、运输、制造毒品一审刑事判决书
# 1       32  （2021）鄂2802刑初165号                  牟恒锐、王妮容留他人吸毒一审刑事判决书
# 2       92   （2021）湘0923刑初46号                  李新、曹勇军容留他人吸毒一审刑事判决书
# 3      146   （2021）湘0421刑初98号  （2021）湘0421刑初98号邱明、刘峻砜容留他人吸毒一审刑事判决书
# 4      338  （2021）湘0481刑初189号               被告人伍健、李小某某贩卖毒品罪一审刑事判决书
# ..     ...                ...                                  ...
# 104   6828  （2021）湘0922刑初132号       石海满、李帅辉走私、贩卖、运输、制造毒品罪刑事一审刑事判决书
# 105   6837  （2021）湘0321刑初242号      王志忠、郭勤龙容留他人吸毒罪、容留他人吸毒罪刑事一审刑事判决书
# 106   6894  （2021）湘0408刑初217号           孙榆茗走私、贩卖、运输、制造毒品罪刑事一审刑事判决书
# 107   6996   （2021）辽0103刑初59号           何川、王誉筱走私、贩卖、运输、制造毒品一审刑事判决书
# 108   6998  （2021）渝0105刑初618号          廖伟,赖晓涛走私、贩卖、运输、制造毒品罪一审刑事判决书
#
#                 法院    所属地区  审理程序        裁判日期         当事人             案由  \
# 0    山东省淄博市张店区人民法院  山东省淄博市  刑事一审  2021-05-06  王吉群；董佳伟；梁浩  走私、贩卖、运输、制造毒品
# 1       湖北省利川市人民法院  湖北省利川市  刑事一审  2021-05-14      牟恒锐；王妮         容留他人吸毒
# 2       湖南省安化县人民法院  湖南省安化县  刑事一审  2021-05-07      李新；曹勇军         容留他人吸毒
# 3       湖南省衡阳县人民法院  湖南省衡阳县  刑事一审  2021-05-07      邱明；刘峻砜         容留他人吸毒
# ..                                                 ...        ...
# 104  指控被告人石海满、李帅辉犯贩卖毒品罪，于2021年5月20日向本院提起公诉。本院经审查，于同...        NaN
# 105  指控被告人王志忠、郭勤龙犯容留他人吸毒罪，于2021年6月24日向本院提起公诉。本院受理后，...    有期徒刑八个月
# 106  指控被告人孙榆茗犯贩卖毒品罪，向本院提起公诉。本院于2021年6月10日受理后，依法适用简易...        NaN
# 107  指控被告人王誉筱、何川犯贩卖毒品罪，于2021年1月11日向本院提起公诉。本院依法组成合议庭...  有期徒刑一年四个月
# 108  指控被告人赖晓涛、廖伟犯贩卖毒品罪，向本院提起公诉。本院适用刑事案件速裁程序，实行独任审判，...    有期徒刑七个月
#
#               罚金              罪名
# 0    罚金人民币10000元  走私、贩卖、运输、制造毒品罪
# 1     罚金人民币3000元         容留他人吸毒罪
# 2       罚金人民币二千元         容留他人吸毒罪
# 3            NaN         容留他人吸毒罪
# 4            NaN  走私、贩卖、运输、制造毒品罪
# ..           ...             ...
# 104          NaN  走私、贩卖、运输、制造毒品罪
# 105     罚金人民币四千元         容留他人吸毒罪
# 106     罚金人民币二千元  走私、贩卖、运输、制造毒品罪
# 107     罚金人民币二万元  走私、贩卖、运输、制造毒品罪
# 108     罚金人民币二千元  走私、贩卖、运输、制造毒品罪
#
# [109 rows x 19 columns]

# %%
import pandas as pd 
import re
def extract_text_segment(text):
    # 使用正则提取 "指控" 到 "公诉机关认为" 之间的内容，包括边界词
    match = re.search(r'公诉机关指控.*?公诉机关认为', text)
    return match.group(0) if match else None

# 应用函数到 DataFrame 的 '文本' 列，生成新列 'NER'
result['NER'] = result['文本'].apply(extract_text_segment)

# %%
result.dropna(inplace=True)
len(result)
# Out:
# 1305

# %%
result.to_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2020年裁判文书数据\毒品final.csv',index=False)

# %%
result['NER'][2]
# Out:
# '公诉机关指控：2019年7月6日下午，被告人刘晓琳与翁某经商议，以人民币1000元的价格贩卖给翁某1包甲基苯丙胺（冰毒），并以微信转账方式支付毒资。后被告人刘晓琳又与被告人刘军联系，以人民币1000元的价格从刘军处购买1包甲基苯丙胺。当日晚，被告人刘军将1包甲基苯丙胺藏匿在本市鄞州区甬港南路紫罗兰休闲中心门口的公交车站座位下，并将藏匿地点告知被告人刘晓琳，刘晓琳又联系翁某自取。 2019年9月5日，公安机关在本市海曙区古林镇宙科公寓8832室将被告人刘军抓获，当场查获可疑晶体1包。经鉴定,该包可疑晶体净重0.03克，检出甲基苯丙胺成分。 案发后，被告人刘晓琳主动至公安机关投案，并如实供述自己的罪行。 被告人刘军、刘晓琳对指控的犯罪事实和证据均没有异议，均自愿认罪认罚。 公诉机关认为'

# %%
df1=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\毒品_final.csv')
df2=pd.read_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\毒品final.csv')
result = pd.concat([df1, df2], axis=0, ignore_index=True)
len(result)
# Out:
# 245

# %%
result.to_csv(r'G:\BaiduNetdiskDownload\中国裁判文书网\2021年裁判文书数据\毒品final1.csv',index=False)

# %% [markdown]
# ## 实体关系构建
